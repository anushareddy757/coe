# %% [markdown]
# # CENSUS_DATA_ANALYSIS :

# %% [markdown]
# ## 1.What is the overall distribution of education levels among the population?

# %%
import pandas as pd
census_data=pd.read_csv("C:/Users/Rahul/OneDrive/Desktop/coe/census.csv")
census_data.columns = [
    "Age",
    "Education",
    "Marital_Status",
    "Gender",
    "Tax_Status",
    "Income",
    "Parental_Status",
    "Country",
    "Citizenship",
    "Weeks_Worked"
]
census_data.head()
# Out:
#    Age               Education Marital_Status  Gender       Tax_Status  \
# 0   73      Highschoolgraduate        Widowed  Female         Nonfiler
# 1   58  Somecollegebutnodegree       Divorced    Male  Headofhousehold
# 2   18               10thgrade   Nevermarried  Female         Nonfiler
# 3    9                Children   Nevermarried  Female         Nonfiler
# 4   10                Children   Nevermarried  Female         Nonfiler
#
#     Income     Parental_Status        Country                   Citizenship  \
# 0  1700.09       Notinuniverse  United-States  Native-BornintheUnitedStates
# 1  1053.55       Notinuniverse  United-States  Native-BornintheUnitedStates
# 2   991.95       Notinuniverse        Vietnam   Foreignborn-NotacitizenofUS
# 3  1758.14  Bothparentspresent  United-States  Native-BornintheUnitedStates
# 4  1069.16  Bothparentspresent  United-States  Native-BornintheUnitedStates
#
#    Weeks_Worked
# 0             0
# 1            52
# 2             0
# ...

# %%
# Get the distribution of education levels

education_distribution = census_data['Education'].value_counts()
education_distribution
# Out:
# Education
# Highschoolgraduate                   483
# Children                             452
# Somecollegebutnodegree               295
# Bachelorsdegree(BAABBS)              206
# 10thgrade                             81
# 7thand8thgrade                        81
# Mastersdegree(MAMSMEngMEdMSWMBA)      68
# 11thgrade                             68
# Associatesdegree-occup/vocational     56
# 9thgrade                              56
# Associatesdegree-academicprogram      50
# 5thor6thgrade                         21
# Profschooldegree(MDDDSDVMLLBJD)       20
# 12thgradenodiploma                    18
# 1st2nd3rdor4thgrade                   16
# Doctoratedegree(PhDEdD)               15
# Lessthan1stgrade                      14
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
education_distribution.plot(kind='bar')
plt.show()

# %%
a=census_data.groupby('Education')['Age'].count()
a.plot(kind='bar')
plt.show()

# %%
a=census_data.groupby(['Education','Gender'])['Age'].count()
a.plot(kind='bar')
plt.show()
# Out:
# Education                          Gender
# 10thgrade                          Female     43
#                                    Male       38
# 11thgrade                          Female     38
#                                    Male       30
# 12thgradenodiploma                 Female      8
#                                    Male       10
# 1st2nd3rdor4thgrade                Female     13
#                                    Male        3
# 5thor6thgrade                      Female     12
#                                    Male        9
# 7thand8thgrade                     Female     42
#                                    Male       39
# 9thgrade                           Female     29
#                                    Male       27
# Associatesdegree-academicprogram   Female     34
#                                    Male       16
# Associatesdegree-occup/vocational  Female     26
#                                    Male       30
# ...

# %% [markdown]
# ## 2. How many people attended college but didn’t graduate (college dropouts)?

# %%
college_dropouts = census_data[census_data['Education'] == 'Somecollegebutnodegree']
college_dropouts.shape[0]
# Out:
# 295

# %% [markdown]
# ## 3. How many employable females exist in the dataset by education level?

# %%
a=census_data[(census_data['Gender']=='Female') & (census_data['Weeks_worked']>0)]
a
b=a['Education'].value_counts()
b
# Out:
# Education
# Highschoolgraduate                   183
# Somecollegebutnodegree               123
# Bachelorsdegree(BAABBS)               84
# Mastersdegree(MAMSMEngMEdMSWMBA)      30
# Associatesdegree-academicprogram      28
# 11thgrade                             20
# Associatesdegree-occup/vocational     19
# 10thgrade                             16
# 7thand8thgrade                        11
# 9thgrade                              10
# Profschooldegree(MDDDSDVMLLBJD)        7
# 5thor6thgrade                          6
# 1st2nd3rdor4thgrade                    5
# 12thgradenodiploma                     5
# Doctoratedegree(PhDEdD)                5
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Does completing higher education correlate with higher income?

# %%
a=census_data.groupby('Education')['Income'].mean().sort_values()
a
# Out:
# Education
# Lessthan1stgrade                     1509.856429
# 12thgradenodiploma                   1583.091667
# 7thand8thgrade                       1583.932099
# 5thor6thgrade                        1587.560476
# Bachelorsdegree(BAABBS)              1596.193204
# Mastersdegree(MAMSMEngMEdMSWMBA)     1601.586912
# Associatesdegree-academicprogram     1640.910000
# Children                             1645.529292
# 9thgrade                             1666.718571
# 11thgrade                            1731.730735
# 10thgrade                            1733.762099
# Associatesdegree-occup/vocational    1777.209821
# 1st2nd3rdor4thgrade                  1787.718750
# Highschoolgraduate                   1837.028385
# Somecollegebutnodegree               1845.371966
# Doctoratedegree(PhDEdD)              1954.134667
# Profschooldegree(MDDDSDVMLLBJD)      2053.327000
# Name: Income, dtype: float64

# %% [markdown]
# ## 5. Are high school graduates earning more than 10th-grade individuals on average?

# %%
avg_income_by_education = census_data.groupby('Education')['Income'].mean()
avg_income_by_education
# Out:
# Education
# 10thgrade                            1733.762099
# 11thgrade                            1731.730735
# 12thgradenodiploma                   1583.091667
# 1st2nd3rdor4thgrade                  1787.718750
# 5thor6thgrade                        1587.560476
# 7thand8thgrade                       1583.932099
# 9thgrade                             1666.718571
# Associatesdegree-academicprogram     1640.910000
# Associatesdegree-occup/vocational    1777.209821
# Bachelorsdegree(BAABBS)              1596.193204
# Children                             1645.529292
# Doctoratedegree(PhDEdD)              1954.134667
# Highschoolgraduate                   1837.028385
# Lessthan1stgrade                     1509.856429
# Mastersdegree(MAMSMEngMEdMSWMBA)     1601.586912
# Profschooldegree(MDDDSDVMLLBJD)      2053.327000
# Somecollegebutnodegree               1845.371966
# Name: Income, dtype: float64

# %%
a=avg_income_by_education.get('10thgrade')
b=avg_income_by_education.get('Highschoolgraduate')

print(a)
print(b)
d=[a,b]
labels = ['10th Grade', 'High School Graduate']
plt.pie(d,labels=labels,autopct='%1.1f%%')
plt.show()
# Out:
# 1733.7620987654323
# 1837.0283850931676

# %%
import matplotlib.pyplot as plt

income_values = [991.95, 898.83]  # example values: 10th grade vs High School
labels = ['10th Grade', 'High School Graduate']

plt.figure(figsize=(6,6))
plt.pie(income_values, labels=labels, autopct='%1.1f%%', startangle=90, colors=['orange','green'])
plt.title('Average Income: 10th Grade vs High School Graduate')
plt.show()

# %% [markdown]
# ## 6. How does marital status vary with education? For example, are divorced or widowed females more likely to have lower education?

# %%
edu_marital_gender = census_data.groupby(['Education', 'Marital_Status', 'Gender']).size()
edu_marital_gender
# Out:
# Education               Marital_Status                 Gender
# 10thgrade               Divorced                       Male       3
#                         Married-civilianspousepresent  Female    16
#                                                        Male      14
#                         Married-spouseabsent           Female     1
#                                                        Male       1
#                                                                  ..
# Somecollegebutnodegree  Nevermarried                   Male      41
#                         Separated                      Female     2
#                                                        Male       1
#                         Widowed                        Female    10
#                                                        Male       1
# Length: 135, dtype: int64

# %%
edu_marital_gender.plot(kind='bar',figsize=(10,6))
plt.show()

# %% [markdown]
# ## 7. In the next 5 years, how many voters will come?

# %%
future_voters = census_data[(census_data['Age'] >= 13) & (census_data['Age'] < 18)]
future_voters.shape[0]
# Out:
# 138

# %% [raw]
# No. of Senior Citizen to get added in next X years
# No. of Voters to get added in next X years
# No. of Employable Female Citizens who are Widows or Divorced
# No. of Orphans for each category based on Parents Present
# Pension Amount to be added after x years
# Gender wise Per Capita Income
# Per Capita Income
# Total Tax To Be collected
# Total Income of different types of Tax Payers
# Gender wise Total Income Generated
# Calculate Sex Ratio (Male : Female)
# Education Qualification Count based on Employment
# Education category-wise gender-wise count
# No of widow female candidates
# No of children parents category-wise gender-wise
# Age above 60 citizens and non-citizens
# No of employable widows and divorced
# No of non-citizens working %
# Money generated for non-citizens
#                Citizens age above 23 having no employment and highest education

# %% [markdown]
# ## No. of Senior Citizen to get added in next 5 years

# %%
census_data[(census_data['Age'] >= 55) & (census_data['Age'] <= 59)].shape[0]
# Out:
# 86

# %% [markdown]
# ## No. of Voters to get added in next X years

# %%
census_data[(census_data['Age'] >= 13) & (census_data['Age'] <= 17)].shape[0]
# Out:
# 138

# %% [markdown]
# ## No. of Orphans for each category based on Parents Present

# %%
census_data[census_data['Parental_Status'] == 'Neitherparentpresent'].groupby('Gender').size()
# Out:
# Gender
# Female     8
# Male      10
# dtype: int64

# %% [markdown]
# ## Pension Amount to be added after x years

# %%
census_data[(census_data['Age'] >= 55) & (census_data['Age'] <= 59)]['Income'].sum()
# Out:
# np.float64(145942.61)

# %% [markdown]
# ## Gender wise Per Capita Income

# %%
census_data.groupby('Gender')['Income'].mean()
# Out:
# Gender
# Female    1671.006890
# Male      1792.955229
# Name: Income, dtype: float64

# %% [markdown]
# ## Per Capita Income

# %%
census_data['Income'].sum() / census_data.shape[0]
# Out:
# np.float64(1728.261635)

# %% [markdown]
# ## Total Tax To Be collected

# %%
census_data.groupby('Tax_Status')['Income'].sum()
# Out:
# Tax_Status
# Headofhousehold            131263.80
# Jointboth65+               114640.78
# Jointbothunder65          1215825.36
# Jointoneunder65&one65+      58549.70
# Nonfiler                  1206593.81
# Single                     729649.82
# Name: Income, dtype: float64

# %% [markdown]
# ## Total Income of different types of Tax Payers

# %%
census_data.groupby('Tax_Status')['Income'].sum()
# Out:
# Tax_Status
# Headofhousehold            131263.80
# Jointboth65+               114640.78
# Jointbothunder65          1215825.36
# Jointoneunder65&one65+      58549.70
# Nonfiler                  1206593.81
# Single                     729649.82
# Name: Income, dtype: float64

# %% [markdown]
# ## Gender wise Total Income Generated

# %%
census_data.groupby('Gender')['Income'].sum()
# Out:
# Gender
# Female    1772938.31
# Male      1683584.96
# Name: Income, dtype: float64

# %% [markdown]
# ## Calculate Sex Ratio (Male : Female)

# %%
male_count = census_data[census_data['Gender']=='Male'].shape[0];
female_count = census_data[census_data['Gender']=='Female'].shape[0]
print(male_count,":",female_count)
# Out:
# 939 : 1061

# %% [markdown]
# ## Education Qualification Count based on Employment

# %%
census_data[census_data['Weeks_Worked'] > 0].groupby('Education').size().sort_values(ascending=False)
# Out:
# Education
# Highschoolgraduate                   350
# Somecollegebutnodegree               240
# Bachelorsdegree(BAABBS)              181
# Mastersdegree(MAMSMEngMEdMSWMBA)      58
# Associatesdegree-occup/vocational     47
# 11thgrade                             42
# Associatesdegree-academicprogram      41
# 10thgrade                             37
# 9thgrade                              25
# 7thand8thgrade                        23
# Profschooldegree(MDDDSDVMLLBJD)       17
# 12thgradenodiploma                    14
# Doctoratedegree(PhDEdD)               13
# 5thor6thgrade                         12
# 1st2nd3rdor4thgrade                    7
# Lessthan1stgrade                       4
# dtype: int64

# %% [markdown]
# ## Education category-wise gender-wise count

# %%
census_data.groupby(['Education', 'Gender']).size()
# Out:
# Education                          Gender
# 10thgrade                          Female     43
#                                    Male       38
# 11thgrade                          Female     38
#                                    Male       30
# 12thgradenodiploma                 Female      8
#                                    Male       10
# 1st2nd3rdor4thgrade                Female     13
#                                    Male        3
# 5thor6thgrade                      Female     12
#                                    Male        9
# 7thand8thgrade                     Female     42
#                                    Male       39
# 9thgrade                           Female     29
#                                    Male       27
# Associatesdegree-academicprogram   Female     34
#                                    Male       16
# Associatesdegree-occup/vocational  Female     26
#                                    Male       30
# ...

# %% [markdown]
# ## No of widow female candidates

# %%
census_data[(census_data['Gender'] == 'Female') & (census_data['Marital_Status'] == 'Widowed')].shape[0]
# Out:
# 75

# %% [markdown]
# ## No of children parents category-wise gender-wise

# %%
census_data[census_data['Age'] < 18].groupby(['Parental_Status', 'Gender']).size()
# Out:
# Parental_Status       Gender
# Bothparentspresent    Female    167
#                       Male      193
# Fatheronlypresent     Female      7
#                       Male       10
# Motheronlypresent     Female     77
#                       Male       56
# Neitherparentpresent  Female      8
#                       Male       10
# Notinuniverse         Female      4
#                       Male        3
# dtype: int64

# %% [markdown]
# ## Age above 60 citizens and non-citizens

# %%
age_above_60 = census_data[census_data['Age'] > 60]
age_above_60
# Out:
#       Age                Education                 Marital_Status  Gender  \
# 0      73       Highschoolgraduate                        Widowed  Female
# 30     63         Lessthan1stgrade  Married-civilianspousepresent    Male
# 34     81  Bachelorsdegree(BAABBS)                        Widowed  Female
# 42     66           7thand8thgrade  Married-civilianspousepresent  Female
# 44     84       Highschoolgraduate  Married-civilianspousepresent  Female
# ...   ...                      ...                            ...     ...
# 1966   75       Highschoolgraduate  Married-civilianspousepresent    Male
# 1971   76           7thand8thgrade                   Nevermarried    Male
# 1973   65       12thgradenodiploma  Married-civilianspousepresent    Male
# 1976   78  Doctoratedegree(PhDEdD)                   Nevermarried    Male
# 1981   75   Somecollegebutnodegree  Married-civilianspousepresent  Female
#
#                   Tax_Status   Income Parental_Status        Country  \
# ...

# %% [markdown]
# ## No of employable widows and divorced

# %%
census_data[(census_data['Marital_Status'].isin(['Widowed','Divorced'])) & (census_data['Weeks_Worked'] > 0)].shape[0]
# Out:
# 123

# %% [markdown]
# ## No of non-citizens working %

# %%
non_citizens = census_data[census_data['Citizenship'] != 'Native-BornintheUnitedStates']; (non_citizens[non_citizens['Weeks_Worked'] > 0].shape[0] / non_citizens.shape[0]) * 100
# Out:
# 61.904761904761905

# %% [markdown]
# ## Money generated for non-citizens

# %%
non_citizens = census_data[census_data['Citizenship'] != 'Native-BornintheUnitedStates']; non_citizens['Income'].sum()
# Out:
# np.float64(361813.26999999996)

# %% [markdown]
# ## Citizens age above 23 having no employment and highest education

# %%
census_data[(census_data['Age'] >= 23) & (census_data['Citizenship'] == 'Native-BornintheUnitedStates') & (census_data['Weeks_Worked'] == 0)].groupby('Education').size().sort_values(ascending=False)
# Out:
# Education
# Highschoolgraduate                   107
# Somecollegebutnodegree                43
# 7thand8thgrade                        35
# 10thgrade                             23
# Bachelorsdegree(BAABBS)               20
# 9thgrade                              14
# 11thgrade                             12
# Mastersdegree(MAMSMEngMEdMSWMBA)      10
# Associatesdegree-occup/vocational      6
# Associatesdegree-academicprogram       6
# 1st2nd3rdor4thgrade                    6
# 5thor6thgrade                          6
# Lessthan1stgrade                       3
# Doctoratedegree(PhDEdD)                2
# Profschooldegree(MDDDSDVMLLBJD)        2
# 12thgradenodiploma                     1
# dtype: int64
